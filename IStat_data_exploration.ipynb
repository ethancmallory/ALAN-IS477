# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
 unemployment = pd.read_csv("Provincial data (IT1,150_915_DF_DCCV_TAXOCCU1_5,1.0).csv")

# %%
unemployment
# Out:
#      FREQ Frequency REF_AREA     Territory DATA_TYPE        Indicator  SEX  \
# 0       A    Annual       IT         Italy     EMP_R  Employment rate    1
# 1       A    Annual       IT         Italy     EMP_R  Employment rate    1
# 2       A    Annual       IT         Italy     EMP_R  Employment rate    1
# 3       A    Annual       IT         Italy     EMP_R  Employment rate    2
# 4       A    Annual       IT         Italy     EMP_R  Employment rate    2
# ...   ...       ...      ...           ...       ...              ...  ...
# 1192    A    Annual    IT111  Sud Sardegna     EMP_R  Employment rate    2
# 1193    A    Annual    IT111  Sud Sardegna     EMP_R  Employment rate    2
# 1194    A    Annual    IT111  Sud Sardegna     EMP_R  Employment rate    9
# 1195    A    Annual    IT111  Sud Sardegna     EMP_R  Employment rate    9
# 1196    A    Annual    IT111  Sud Sardegna     EMP_R  Employment rate    9
#
# ...

# %%
output = pd.read_csv("Output and value added by industry (IT1,92_1225_DF_DCCN_ANA1_1,1.0)(1).csv",
    quotechar="'"
)

# %%
unemployment['Territory'].unique()
# Out:
# array(['Italy', 'Nord', 'Nord-ovest', 'Piemonte', 'Torino', 'Vercelli',
#        'Novara', 'Cuneo', 'Asti', 'Alessandria', 'Biella',
#        'Verbano-Cusio-Ossola', '\'Valle d"\'Aosta / Vallée d"\'Aoste\'',
#        'Liguria', 'Imperia', 'Savona', 'Genova', 'La Spezia', 'Lombardia',
#        'Varese', 'Como', 'Sondrio', 'Milano', 'Bergamo', 'Brescia',
#        'Pavia', 'Cremona', 'Mantova', 'Lecco', 'Lodi',
#        'Monza e della Brianza', 'Nord-est',
#        'Trentino Alto Adige / Südtirol',
#        'Provincia Autonoma Bolzano / Bozen', 'Provincia Autonoma Trento',
#        'Veneto', 'Verona', 'Vicenza', 'Belluno', 'Treviso', 'Venezia',
#        'Padova', 'Rovigo', 'Friuli-Venezia Giulia', 'Udine', 'Gorizia',
#        'Trieste', 'Pordenone', 'Emilia-Romagna', 'Piacenza', 'Parma',
#        '\'Reggio nell"\'Emilia\'', 'Modena', 'Bologna', 'Ferrara',
#        'Ravenna', 'Forlì-Cesena', 'Rimini', 'Centro (I)', 'Toscana',
# ...

# %%
sns.barplot(data = unemployment, x="Territory", y= "Observation")

plt.xticks(rotation=45)
plt.show()

# %%
output
# Out:
#     FREQ Frequency REF_AREA Territory DATA_TYPE_AGGR          Aggregate  \
# 0      A    Annual       IT     Italy    B1G_B_W2_S1  Gross value added
# 1      A    Annual       IT     Italy    B1G_B_W2_S1  Gross value added
# 2      A    Annual       IT     Italy    B1G_B_W2_S1  Gross value added
# 3      A    Annual       IT     Italy    B1G_B_W2_S1  Gross value added
# 4      A    Annual       IT     Italy    B1G_B_W2_S1  Gross value added
# ..   ...       ...      ...       ...            ...                ...
# 839    A    Annual       IT     Italy    B1G_B_W2_S1  Gross value added
# 840    A    Annual       IT     Italy    B1G_B_W2_S1  Gross value added
# 841    A    Annual       IT     Italy    B1G_B_W2_S1  Gross value added
# 842    A    Annual       IT     Italy    B1G_B_W2_S1  Gross value added
# 843    A    Annual       IT     Italy    B1G_B_W2_S1  Gross value added
#
#     BRKDW_INDUSTRY_NACE_REV2  \
# 0                         _T
# 1                         _T
# ...

# %%
supply_side_gdp = pd.read_csv("Gross domestic product supply side (IT1,93_498_DF_DCCN_PILT_1,1.0)(1).csv")

# %%
supply_side_gdp
# Out:
#      FREQ Frequency REF_AREA    Territory DATA_TYPE_AGGR  \
# 0       A    Annual       IT        Italy   B1GQ_B_W2_S1
# 1       A    Annual       IT        Italy   B1GQ_B_W2_S1
# 2       A    Annual       IT        Italy   B1GQ_B_W2_S1
# 3       A    Annual       IT        Italy   B1GQ_B_W2_S1
# 4       A    Annual       IT        Italy   B1GQ_B_W2_S1
# ...   ...       ...      ...          ...            ...
# 1278    A    Annual      ITZ  Extra-Regio   B1GQ_B_W2_S1
# 1279    A    Annual      ITZ  Extra-Regio   B1GQ_B_W2_S1
# 1280    A    Annual      ITZ  Extra-Regio   B1GQ_B_W2_S1
# 1281    A    Annual      ITZ  Extra-Regio   B1GQ_B_W2_S1
# 1282    A    Annual      ITZ  Extra-Regio   B1GQ_B_W2_S1
#
#                                     Aggregate VALUATION Valuation (DESC)  \
# 0     Gross domestic product at market prices         V   Current prices
# 1     Gross domestic product at market prices         V   Current prices
# ...

# %%
employee_compensation = pd.read_csv("Compensation of employees and its components by industry (IT1,93_1227_DF_DCCN_TNA1_2,1.0).csv",
    quotechar="'")

# %%
employee_compensation
# Out:
#     FREQ Frequency REF_AREA Territory DATA_TYPE_AGGR  \
# 0      A    Annual       IT     Italy     D1_D_W2_S1
# 1      A    Annual       IT     Italy     D1_D_W2_S1
# 2      A    Annual       IT     Italy     D1_D_W2_S1
# 3      A    Annual       IT     Italy     D1_D_W2_S1
# 4      A    Annual       IT     Italy     D1_D_W2_S1
# ..   ...       ...      ...       ...            ...
# 382    A    Annual       IT     Italy     D1_D_W2_S1
# 383    A    Annual       IT     Italy     D1_D_W2_S1
# 384    A    Annual       IT     Italy     D1_D_W2_S1
# 385    A    Annual       IT     Italy     D1_D_W2_S1
# 386    A    Annual       IT     Italy     D1_D_W2_S1
#
#                               Aggregate BRKDW_INDUSTRY_NACE_REV2  \
# 0    Domestic compensation of employees                       _T
# 1    Domestic compensation of employees                       _T
# 2    Domestic compensation of employees                       _T
# ...
