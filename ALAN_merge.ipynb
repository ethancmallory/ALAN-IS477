# %%
import pandas as pd

# %%
employee_compensation = pd.read_csv("Compensation of employees and its components by industry (IT1,92_1225_DF_DCCN_ANA1_2,1.0).csv",encoding="utf-8-sig", quotechar="'", on_bad_lines="skip")
employee_compensation = employee_compensation[employee_compensation["BRKDW_INDUSTRY_NACE_REV2"] == "_T"][["TIME_PERIOD", "Observation"]].rename(columns={"Observation": "compensation_euros"})
employee_compensation
# Out:
#       TIME_PERIOD  compensation_euros
# 0            2016            665223.5
# 1            2017            682754.8
# 2            2018            703650.4
# 3            2019            718956.8
# 4            2020            677961.2
# ...           ...                 ...
# 3035         2020             12367.9
# 3036         2021             13714.1
# 3037         2022             16278.6
# 3038         2023             15148.2
# 3039         2024             15870.6
#
# [68 rows x 2 columns]

# %%
value_added  = pd.read_csv("Output and value added by industry (IT1,92_1225_DF_DCCN_ANA1_1,1.0).csv", encoding="utf-8-sig", on_bad_lines="skip")
value_added   = value_added[value_added["BRKDW_INDUSTRY_NACE_REV2"] == "_T"][["TIME_PERIOD", "Observation"]].rename(columns={"Observation": "gross_value_added_euros"})
value_added
# Out:
#       TIME_PERIOD  gross_value_added_euros
# 0            2016                3260318.6
# 1            2017                3353545.8
# 2            2018                3395738.2
# 3            2019                3408472.1
# 4            2020                3143279.3
# ...           ...                      ...
# 8959         2021                1607816.2
# 8960         2022                1702253.6
# 8961         2023                1783264.3
# 8962         2024                1900954.9
# 8963         2025                1938607.4
#
# [432 rows x 2 columns]

# %%
gdp_supply_side  = pd.read_csv("Gross domestic product supply side (IT1,93_498_DF_DCCN_PILT_1,1.0).csv", encoding="utf-8-sig", on_bad_lines="skip")
gdp_supply_side  = gdp_supply_side[gdp_supply_side["REF_AREA"] == "IT"][["TIME_PERIOD", "Observation"]].rename(columns={"Observation": "gdp_euros"})
gdp_supply_side
# Out:
#    TIME_PERIOD  gdp_euros
# 0         2015  1663277.7
# 1         2016  1704856.7
# 2         2017  1744493.0
# 3         2018  1777744.4
# 4         2019  1804066.8
# 5         2020  1670011.9
# 6         2021  1842507.4
# 7         2022  1998072.6
# 8         2023  2142601.7
# 9         2024  2199619.4

# %%
world_bank  = pd.read_csv("World_Bank_Econ.csv", encoding="utf-8-sig")
world_bank
# Out:
#      FREQ FREQ_LABEL REF_AREA REF_AREA_LABEL           INDICATOR  \
# 0       A     Annual      ABW          Aruba   WB_CCDFS_DEBTDUEY
# 1       A     Annual      ABW          Aruba       WB_CCDFS_FBMA
# 2       A     Annual      ABW          Aruba        WB_CCDFS_FBY
# 3       A     Annual      ABW          Aruba      WB_CCDFS_GGDMA
# 4       A     Annual      ABW          Aruba       WB_CCDFS_GGDY
# ...   ...        ...      ...            ...                 ...
# 3370    A     Annual      ZWE       Zimbabwe  WB_CCDFS_STDEBTALL
# 3371    A     Annual      ZWE       Zimbabwe  WB_CCDFS_STDEBTRES
# 3372    A     Annual      ZWE       Zimbabwe  WB_CCDFS_XTDEBTRES
# 3373    A     Annual      ZWE       Zimbabwe  WB_CCDFS_XTDEBTRXG
# 3374    A     Annual      ZWE       Zimbabwe    WB_CCDFS_XTDEBTY
#
#                                         INDICATOR_LABEL UNIT_MEASURE  \
# 0     Central government debt maturing in 12 months ...           PT
# 1       Fiscal balance, % of 10-year moving average GDP           PT
# 2                              Fiscal balance, % of GDP           PT
# 3     General government gross debt, % of 10-year mo...           PT
# 4               General government gross debt, % of GDP           PT
# ...                                                 ...          ...
# 3370        Short-term external debt stocks, % of total           PT
# 3371     Short-term external debt stocks, % of reserves           PT
# 3372          Total external debt stocks, % of reserves           PT
# 3373  Total external debt stocks, % of reserves excl...           PT
# 3374               Total external debt stocks, % of GDP           PT
#
#      UNIT_MEASURE_LABEL DATABASE_ID                         DATABASE_ID_LABEL  \
# 0            Percentage    WB_CCDFS  A Cross-Country Database of Fiscal Space
# 1            Percentage    WB_CCDFS  A Cross-Country Database of Fiscal Space
# 2            Percentage    WB_CCDFS  A Cross-Country Database of Fiscal Space
# 3            Percentage    WB_CCDFS  A Cross-Country Database of Fiscal Space
# 4            Percentage    WB_CCDFS  A Cross-Country Database of Fiscal Space
# ...                 ...         ...                                       ...
# 3370         Percentage    WB_CCDFS  A Cross-Country Database of Fiscal Space
# 3371         Percentage    WB_CCDFS  A Cross-Country Database of Fiscal Space
# 3372         Percentage    WB_CCDFS  A Cross-Country Database of Fiscal Space
# 3373         Percentage    WB_CCDFS  A Cross-Country Database of Fiscal Space
# 3374         Percentage    WB_CCDFS  A Cross-Country Database of Fiscal Space
#
#       ...         2013         2014         2015         2016         2017  \
# 0     ...     2.796921     0.333214     1.083226     1.075603     1.678525
# 1     ...    -6.446430    -7.966341    -1.634916    -1.593364    -2.891918
# 2     ...    -6.048000    -7.459000    -1.475000    -1.455000    -2.587000
# 3     ...    74.645564    83.005679    82.219094    82.555968    84.762163
# 4     ...    70.032000    77.709000    74.177000    75.387000    75.825000
# ...   ...          ...          ...          ...          ...          ...
# 3370  ...    32.636767    31.570034    31.849468    27.393202    29.775457
# 3371  ...   578.450011   725.270846   707.061644   771.444210  1273.252040
# 3372  ...  1772.387625  2297.339440  2220.010832  2816.188492  4276.179731
# 3373  ...  1774.203247  2300.416472  2307.273588  2819.385956  4283.828716
# 3374  ...    44.090958    42.866170    48.314178    55.788515    58.513026
#
#               2018         2019          2020         2021        2022
# 0         1.398046     1.348645      3.282532     2.707058    2.369535
# 1        -3.079565    -0.285148    -14.299284    -9.635033   -0.541551
# 2        -2.641000    -0.243000    -16.230000    -9.161000   -0.465000
# 3        85.483871    83.377121     98.975189   107.084439  104.945632
# 4        73.310000    71.053000    112.339000   101.816000   90.111000
# ...            ...          ...           ...          ...         ...
# 3370     26.807020    28.752587     30.224142    27.190692         NaN
# 3371   3891.554379  2328.310564  11529.869386   445.367863         NaN
# 3372  14516.922755  8097.742804  38147.880109  1637.942371         NaN
# 3373  14603.671157  8130.739227  39900.732457  1641.953936         NaN
# 3374     34.082957    47.022719     47.364086    38.173762         NaN
#
# [3375 rows x 49 columns]

# %%
year_cols = [c for c in world_bank.columns if c.isdigit()]
world_bank = world_bank[world_bank["REF_AREA"] == "ITA"].melt(id_vars=["INDICATOR"], value_vars=year_cols, var_name="TIME_PERIOD", value_name="value")
world_bank = world_bank.pivot_table(index="TIME_PERIOD", columns="INDICATOR", values="value").reset_index()
world_bank["TIME_PERIOD"] = world_bank["TIME_PERIOD"].astype(int)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'REF_AREA'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[30], line 2
#       1 year_cols = [c for c in world_bank.columns if c.isdigit()]
# ----> 2 world_bank = world_bank[world_bank["REF_AREA"] == "ITA"].melt(id_vars=["INDICATOR"], value_vars=year_cols, var_name="TIME_PERIOD", value_name="value")
#       3 world_bank = world_bank.pivot_table(index="TIME_PERIOD", columns="INDICATOR", values="value").reset_index()
#       4 world_bank["TIME_PERIOD"] = world_bank["TIME_PERIOD"].astype(int)
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/core/frame.py:4113, in DataFrame.__getitem__(self, key)
#    4111 if self.columns.nlevels > 1:
#    4112     return self._getitem_multilevel(key)
# -> 4113 indexer = self.columns.get_loc(key)
#    4114 if is_integer(indexer):
#    4115     indexer = [indexer]
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/core/indexes/base.py:3819, in Index.get_loc(self, key)
#    3814     if isinstance(casted_key, slice) or (
#    3815         isinstance(casted_key, abc.Iterable)
#    3816         and any(isinstance(x, slice) for x in casted_key)
#    3817     ):
#    3818         raise InvalidIndexError(key)
# -> 3819     raise KeyError(key) from err
#    3820 except TypeError:
#    3821     # If we have a listlike key, _check_indexing_error will raise
#    3822     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3823     #  the TypeError.
#    3824     self._check_indexing_error(key)
#
# KeyError: 'REF_AREA'

# %%
merged = employee_compensation.merge(value_added, on="TIME_PERIOD", how="outer")
# Out:
#       TIME_PERIOD  compensation_euros  gross_value_added_euros
# 0            2016            665223.5                3260318.6
# 1            2016            665223.5                3260318.6
# 2            2016            665223.5                3260318.6
# 3            2016            665223.5                3260318.6
# 4            2016            665223.5                3237783.9
# ...           ...                 ...                      ...
# 3175         2025            900444.3                1720348.7
# 3176         2025            900444.3                2014632.8
# 3177         2025            900444.3                1977306.8
# 3178         2025            900444.3                1976737.7
# 3179         2025            900444.3                1938607.4
#
# [3180 rows x 3 columns]

# %%
merged = merged.merge(gdp_supply_side, on="TIME_PERIOD", how="outer")
# Out:
#       TIME_PERIOD  compensation_euros  gross_value_added_euros  gdp_euros_x  \
# 0            2015                 NaN                      NaN    1663277.7
# 1            2016            665223.5                3260318.6    1704856.7
# 2            2016            665223.5                3260318.6    1704856.7
# 3            2016            665223.5                3260318.6    1704856.7
# 4            2016            665223.5                3260318.6    1704856.7
# ...           ...                 ...                      ...          ...
# 3176         2025            900444.3                1720348.7          NaN
# 3177         2025            900444.3                2014632.8          NaN
# 3178         2025            900444.3                1977306.8          NaN
# 3179         2025            900444.3                1976737.7          NaN
# 3180         2025            900444.3                1938607.4          NaN
#
#       gdp_euros_y
# 0       1663277.7
# 1       1704856.7
# 2       1704856.7
# 3       1704856.7
# 4       1704856.7
# ...           ...
# 3176          NaN
# 3177          NaN
# 3178          NaN
# 3179          NaN
# 3180          NaN
#
# [3181 rows x 5 columns]

# %%
merged = merged.merge(world_bank, on="TIME_PERIOD", how="outer")
merged
# Out:
#       TIME_PERIOD  compensation_euros  gross_value_added_euros  gdp_euros_x  \
# 0            1990                 NaN                      NaN          NaN
# 1            1991                 NaN                      NaN          NaN
# 2            1992                 NaN                      NaN          NaN
# 3            1993                 NaN                      NaN          NaN
# 4            1994                 NaN                      NaN          NaN
# ...           ...                 ...                      ...          ...
# 3201         2025            900444.3                1720348.7          NaN
# 3202         2025            900444.3                2014632.8          NaN
# 3203         2025            900444.3                1977306.8          NaN
# 3204         2025            900444.3                1976737.7          NaN
# 3205         2025            900444.3                1938607.4          NaN
#
#       gdp_euros_y  WB_CCDFS_AVGLIFE_x  WB_CCDFS_CBY_x  WB_CCDFS_DEBTDUEY_x  \
# 0             NaN                 NaN      -12.076512                  NaN
# 1             NaN                 NaN      -11.645166                  NaN
# 2             NaN                 NaN      -10.034919                  NaN
# 3             NaN                 NaN       -8.413320                  NaN
# 4             NaN                 NaN       -7.829716                  NaN
# ...           ...                 ...             ...                  ...
# 3201          NaN                 NaN             NaN                  NaN
# 3202          NaN                 NaN             NaN                  NaN
# 3203          NaN                 NaN             NaN                  NaN
# 3204          NaN                 NaN             NaN                  NaN
# 3205          NaN                 NaN             NaN                  NaN
#
#       WB_CCDFS_DFFB_x  WB_CCDFS_DFGGD_x  ...  WB_CCDFS_PBY_y  \
# 0          -39.401628        359.701808  ...          -1.783
# 1          -39.193341        372.428523  ...          -0.472
# 2          -35.677166        399.512950  ...           1.307
# 3          -34.490987        438.907518  ...           2.068
# 4          -31.232524        462.691118  ...           1.518
# ...               ...               ...  ...             ...
# 3201              NaN               NaN  ...             NaN
# 3202              NaN               NaN  ...             NaN
# 3203              NaN               NaN  ...             NaN
# 3204              NaN               NaN  ...             NaN
# 3205              NaN               NaN  ...             NaN
#
#       WB_CCDFS_PRDEBTY_y  WB_CCDFS_PSCY_y  WB_CCDFS_SECNRES_y  \
# 0                    NaN             68.0                 NaN
# 1                    NaN             70.4                 NaN
# 2                    NaN             74.5                 NaN
# 3                    NaN             74.9                 NaN
# 4                    NaN             71.5                 NaN
# ...                  ...              ...                 ...
# 3201                 NaN              NaN                 NaN
# 3202                 NaN              NaN                 NaN
# 3203                 NaN              NaN                 NaN
# 3204                 NaN              NaN                 NaN
# 3205                 NaN              NaN                 NaN
#
#       WB_CCDFS_SOVRATE_y  WB_CCDFS_STDEBTALL_y  WB_CCDFS_STDEBTRES_y  \
# 0              20.500000                   NaN                   NaN
# 1              20.247945                   NaN                   NaN
# 2              19.614754                   NaN                   NaN
# 3              18.252054                   NaN                   NaN
# 4              18.333333                   NaN                   NaN
# ...                  ...                   ...                   ...
# 3201                 NaN                   NaN                   NaN
# 3202                 NaN                   NaN                   NaN
# 3203                 NaN                   NaN                   NaN
# 3204                 NaN                   NaN                   NaN
# 3205                 NaN                   NaN                   NaN
#
#       WB_CCDFS_XTDEBTRES_y  WB_CCDFS_XTDEBTRXG_y  WB_CCDFS_XTDEBTY_y
# 0                      NaN                   NaN                 NaN
# 1                      NaN                   NaN                 NaN
# 2                      NaN                   NaN                 NaN
# 3                      NaN                   NaN                 NaN
# 4                      NaN                   NaN                 NaN
# ...                    ...                   ...                 ...
# 3201                   NaN                   NaN                 NaN
# 3202                   NaN                   NaN                 NaN
# 3203                   NaN                   NaN                 NaN
# 3204                   NaN                   NaN                 NaN
# 3205                   NaN                   NaN                 NaN
#
# [3206 rows x 47 columns]

# %%
merged.to_csv("italy_economic_data.csv", index=False)
